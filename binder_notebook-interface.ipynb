# %% [markdown]
# # Capstone Project: Face Mask Detection

# %% [markdown]
# ### Performance of the transfer learning model on validation dataset including 267 photos

# %%
import util.source
util.source.plot_confusion_matrix()
# Out:
# TN: 124  FP: 3  FN: 1  TP: 139

# %% [markdown]
# ### Examples with the test dataset including 15 photos

# %%
from util.source import plot_example

path = "./test/subimages"
batch_size=15
image_number = 14

fig = plot_example(path, batch_size, image_number)
